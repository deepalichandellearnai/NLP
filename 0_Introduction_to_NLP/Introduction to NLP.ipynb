# %% [markdown]
# # Topic Overview
#
# - Natural Language Processing
# - Need of NLP
# - Natural Language
# - Natural Language Understanding
# - Natural language Generation
# - Applications of NLP
# - Use Cases of NLP
# - NLP Libraries

# %% [markdown]
# ## Natural Language Processing

# %% [markdown]
# Natural language processing is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data i.e text, speech.

# %% [markdown]
# It gives the machines the ability to read, understand human/natural languages, and generate human/natural language text.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Need of NLP

# %% [markdown]
# A lot of information in the world is unstructured 79% data in the form of messages, tweets, etc... that too in textual form: we need to get this data and extract information from it.
#
# So, how can we understand unstructured text and extract data from it. Well NLP can help in this case..

# %% [markdown]
# ## Natural Language
#
# A natural language or ordinary language is any language that has evolved naturally in humans through use and repetition without conscious planning or premeditation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Natural Language Understanding
#
# NLU is a subtopic of natural-language processing in artificial intelligence.
#
# Natural Language Understanding (NLU) is defined by Gartner as “**the comprehension of the structure and meaning of human language by computers** (e.g., English, Spanish, Japanese), allowing users to interact with the computer using natural sentences”.

# %% [markdown]
# ## Natural Language Generation
#
# Natural Language Generation (NLG), a subfield of artificial intelligence (AI), **It generates the human language text from structured data** generated by the system to respond. It is a software **process that automatically transforms data into plain-English content. The technology can actually tell a story – exactly like that of a human analyst – by writing the sentences and paragraphs for you.**

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Applications of NLP
#
# - Text/Document Classification
# ![image.png](attachment:image.png)
# - Text Summarization
# - Information Extraction
# - AI Chatbot
# - Text Similarity
# - sentiment Analysis

# %% [markdown]
# ![image.png](attachment:image.png)
# - Semantic Analysis

# %% [markdown]
# - Language Translation
# - Speech to Text/ Text to Speech
# - Machine Comprehension(Q&A)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Use Cases of NLP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# NLP can help you with lots of tasks and the fields of application just seem to increase on a daily basis. Let’s mention some examples:
#
# - **NLP enables the recognition and prediction of diseases based on electronic health records and patient’s own speech.** `1
#
# - Organizations can **determine review from customers** about a service or product by identifying and extracting information in sources like social media. **This sentiment analysis can provide a lot of information about customers choices and their decision drivers.**
#
# - An inventor at **IBM developed a cognitive assistant that works like a personalized search engine by learning all about you** and then remind you of a name, a song, or anything you can’t remember the moment you need it to.
#
# - Companies like Yahoo and Google filter and **classify your emails with NLP** by analyzing text in emails that flow through their servers and stopping spam before they even enter your inbox.
#
# - To help to **identify fake news**, the NLP Group at MIT developed a new system to determine if a source is accurate or politically biased, detecting if a news source can be trusted or not.
#
# - Amazon’s Alexa and Apple’s Siri are examples of **intelligent voice driven interfaces** that use NLP to respond to vocal prompts and do everything like find a particular shop, tell us the weather forecast, suggest the best route to the office, or turn on the lights at home.
#
# - NLP is also being used in both the **search and selection phases of talent recruitment**, identifying the skills of potential hires and also spotting prospects before they become active on the job market.
#
# - much more...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## NLP Libraries in Python

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### glove
#
# GloVe represents global vectors and it is actually a algorithm to get Word2vec model and also a trained model named as GloVe model and to load that model GloVe is available as library as well

# %% [markdown]
# ### PyTorch

# %% [markdown]
# One major advantage that Pytorch has over Keras and Tensorflow is that **it has a very rich ecosystem of helper libraries** designed to make your life a lot easier.
#
# **Torchtext and TorchNLP are two libraries that help you preprocess textual data and to transform it with a few simple lines.** They also offer a wide range of commonly used layers in NLP such as Attention layers and several different types of embedding layers.
#
# Whereas, **PyTorch is easier to learn and lighter** to work with, and hence, is relatively **better for passion projects and building rapid prototypes.**

# %% [markdown]
# ### Tensorflow

# %% [markdown]
# Tensorflow is much **better for production models and scalability.** It was built to be production ready.

# %% [markdown]
# ### fastText

# %% [markdown]
# fastText is a **library for learning of word embeddings and text classification created by Facebook's AI Research lab.** The model allows one to create an unsupervised learning or supervised learning algorithm for obtaining vector representations for words. **Facebook makes available pretrained models for 294 languages.**

# %% [markdown]
# ### transformers
#
# transformers is a library developed by HuggingFace to load any transformer based model like BERT, GTP, ELMO, etc...

# %% [markdown]
# ---

# %% [markdown]
# - firstly nltk came, it was just based on linguistic and  language grammer.
#
# - then Gensim ,glove, coreNLP came. pytorch and tensorflow were also being used during that time.
#
# - then Spacy came and it was advanced version of NLTK, along with that fastText also came. Based on deep learning algorithms like LSTM libraries of deep learning pytorch, tensorflow were also being used during that time.
#
# - then Transformers library came. pytorch, tensorflow were also being used during that time.
